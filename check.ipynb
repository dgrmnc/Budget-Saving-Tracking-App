# %%
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Users/umutcandegirmenci/myfirstapp/Py-BudgetSavingApp'

# %%
df = pd.read_excel('/Users/umutcandegirmenci/myfirstapp/budget_report.xlsx')
df
# Out:
#    Income  Income Type  Expenses                       Expenses Type  \
# 0   25000       salary     15000                                rent
# 1   25000       salary      5000           food,bills and everything
# 2    7500  outside gig      1500  covers gas, transactions fees etc.
#
#    Remaining Budget Insertion_Date Insertion_Month  Saving  \
# 0             10000     24-12-2024        December    1750
# 1              5000     24-12-2024        December    1750
# 2              6000     24-12-2024        December    3000
#
#    Rem Budget(After Saving)
# 0                      3250
# 1                      3250
# 2                      3000

# %%
plt.figure(figsize=(12,8))
sns.barplot(data=df, x = 'Insertion_Month', hue = 'Income Type'
                         , y = 'Saving',palette= 'Set3')
plt.title("Monthly Saving Performance")
plt.xlabel('Saving Insertion Month')
plt.ylabel('Saving Total Amount')
plt.xticks()
plt.tight_layout()
plt.show()
